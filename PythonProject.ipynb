# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
link="https://news.ycombinator.com"

# %%
page=requests.get(link)

# %%
soup=bs(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <html lang="en" op="news">
#  <head>
#   <meta content="origin" name="referrer"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="news.css?NuJxPWD6iCYOtPYI8iS2" rel="stylesheet" type="text/css"/>
#   <link href="favicon.ico" rel="shortcut icon"/>
#   <link href="rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <title>
#    Hacker News
#   </title>
#  </head>
#  <body>
#   <center>
#    <table bgcolor="#f6f6ef" border="0" cellpadding="0" cellspacing="0" id="hnmain" width="85%">
#     <tr>
#      <td bgcolor="#ff6600">
#       <table border="0" cellpadding="0" cellspacing="0" style="padding:2px" width="100%">
#        <tr>
#         <td style="width:18px;padding-right:4px">
#          <a href="https://news.ycombinator.com">
#           <img height="18" src="y18.gif" style="border:1px white solid;" width="18"/>
#          </a>
#         </td>
#         <td style="line-height:12pt; height:10px;">
#          <span class="pagetop">
#           <b class="hnname">
#            <a href="news">
#             Hacker News
#            </a>
#           </b>
#           <a href="newest">
#            new
#           </a>
#           |
#           <a href="front">
#            past
#           </a>
#           |
#           <a href="newcomments">
#            comments
#           </a>
#           |
#           <a href="ask">
#            ask
#           </a>
#           |
#           <a href="show">
#            show
#           </a>
#           |
#           <a href="jobs">
#            jobs
#           </a>
#           |
#           <a href="submit">
#            submit
#           </a>
#          </span>
#         </td>
#         <td style="text-align:right;padding-right:4px;">
#          <span class="pagetop">
#           <a href="login?goto=news">
#            login
#           </a>
#          </span>
#         </td>
#        </tr>
#       </table>
#      </td>
#     </tr>
#     <tr id="pagespace" style="height:10px" title="">
#     </tr>
#     <tr>
#      <td>
#       <table border="0" cellpadding="0" cellspacing="0" class="itemlist">
#        <tr class="athing" id="24097420">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           1.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24097420&amp;how=up&amp;goto=news" id="up_24097420">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.preetamnath.com/blog/fire-your-bad-customers">
#           Fire your bad customers
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=preetamnath.com">
#            <span class="sitestr">
#             preetamnath.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24097420">
#           114 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=grwthckrmstr">
#           grwthckrmstr
#          </a>
#          <span class="age">
#           <a href="item?id=24097420">
#            2 hours ago
#           </a>
#          </span>
#          <span id="unv_24097420">
#          </span>
#          |
#          <a href="hide?id=24097420&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24097420">
#           61 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24096935">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           2.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24096935&amp;how=up&amp;goto=news" id="up_24096935">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://rarehistoricalphotos.com/hans-hildenbrand-german-front-in-rare-color-photos-1914-1918/">
#           The German front in rare color photos, 1914-1918
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=rarehistoricalphotos.com">
#            <span class="sitestr">
#             rarehistoricalphotos.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24096935">
#           115 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=pmoriarty">
#           pmoriarty
#          </a>
#          <span class="age">
#           <a href="item?id=24096935">
#            5 hours ago
#           </a>
#          </span>
#          <span id="unv_24096935">
#          </span>
#          |
#          <a href="hide?id=24096935&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24096935">
#           14 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24097573">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           3.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24097573&amp;how=up&amp;goto=news" id="up_24097573">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="http://www.wired.com/story/theres-no-such-thing-as-a-tech-expert-anymore">
#           There’s no such thing as a tech expert anymore
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=wired.com">
#            <span class="sitestr">
#             wired.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24097573">
#           35 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=snadahalli">
#           snadahalli
#          </a>
#          <span class="age">
#           <a href="item?id=24097573">
#            2 hours ago
#           </a>
#          </span>
#          <span id="unv_24097573">
#          </span>
#          |
#          <a href="hide?id=24097573&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24097573">
#           29 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24096328">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           4.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24096328&amp;how=up&amp;goto=news" id="up_24096328">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://twiktwok.github.io/">
#           Twitter x TikTok = Twiktwok
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=twiktwok.github.io">
#            <span class="sitestr">
#             twiktwok.github.io
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24096328">
#           230 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=9nGQluzmnq3M">
#           9nGQluzmnq3M
#          </a>
#          <span class="age">
#           <a href="item?id=24096328">
#            7 hours ago
#           </a>
#          </span>
#          <span id="unv_24096328">
#          </span>
#          |
#          <a href="hide?id=24096328&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24096328">
#           68 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24096082">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           5.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24096082&amp;how=up&amp;goto=news" id="up_24096082">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://voice.mozilla.org/firefox-voice/">
#           Firefox Voice
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=voice.mozilla.org">
#            <span class="sitestr">
#             voice.mozilla.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24096082">
#           159 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=makeworld">
#           makeworld
#          </a>
#          <span class="age">
#           <a href="item?id=24096082">
#            8 hours ago
#           </a>
#          </span>
#          <span id="unv_24096082">
#          </span>
#          |
#          <a href="hide?id=24096082&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24096082">
#           75 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24096154">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           6.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24096154&amp;how=up&amp;goto=news" id="up_24096154">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.darpa.mil/attachments/Real%20Time%20Machine%20Learning%20Proposers%20Day_v3.pdf">
#           Real Time Machine Learning (2019) [pdf]
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=darpa.mil">
#            <span class="sitestr">
#             darpa.mil
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24096154">
#           105 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=apsec112">
#           apsec112
#          </a>
#          <span class="age">
#           <a href="item?id=24096154">
#            8 hours ago
#           </a>
#          </span>
#          <span id="unv_24096154">
#          </span>
#          |
#          <a href="hide?id=24096154&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24096154">
#           13 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24094323">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           7.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24094323&amp;how=up&amp;goto=news" id="up_24094323">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://the-other-side.blog/upi-the-basics/">
#           UPI: India's Unified Payments Interface
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=the-other-side.blog">
#            <span class="sitestr">
#             the-other-side.blog
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24094323">
#           240 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=zero_kool">
#           zero_kool
#          </a>
#          <span class="age">
#           <a href="item?id=24094323">
#            12 hours ago
#           </a>
#          </span>
#          <span id="unv_24094323">
#          </span>
#          |
#          <a href="hide?id=24094323&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24094323">
#           122 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24096899">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           8.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24096899&amp;how=up&amp;goto=news" id="up_24096899">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://advances.sciencemag.org/content/early/2020/08/07/sciadv.abd3083">
#           Low-cost measurement of facemask efficacy for filtering expelled droplets
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=sciencemag.org">
#            <span class="sitestr">
#             sciencemag.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24096899">
#           35 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=pat2man">
#           pat2man
#          </a>
#          <span class="age">
#           <a href="item?id=24096899">
#            5 hours ago
#           </a>
#          </span>
#          <span id="unv_24096899">
#          </span>
#          |
#          <a href="hide?id=24096899&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24096899">
#           10 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24090039">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           9.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24090039&amp;how=up&amp;goto=news" id="up_24090039">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://typing-is-hard.ch/">
#           Typing Is Hard
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=typing-is-hard.ch">
#            <span class="sitestr">
#             typing-is-hard.ch
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24090039">
#           147 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=lelf">
#           lelf
#          </a>
#          <span class="age">
#           <a href="item?id=24090039">
#            9 hours ago
#           </a>
#          </span>
#          <span id="unv_24090039">
#          </span>
#          |
#          <a href="hide?id=24090039&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24090039">
#           32 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24094377">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           10.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24094377&amp;how=up&amp;goto=news" id="up_24094377">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://romefrontend.dev/blog/2020/08/08/introducing-rome.html">
#           Rome: A Linter for JavaScript and TypeScript
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=romefrontend.dev">
#            <span class="sitestr">
#             romefrontend.dev
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24094377">
#           201 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=acemarke">
#           acemarke
#          </a>
#          <span class="age">
#           <a href="item?id=24094377">
#            12 hours ago
#           </a>
#          </span>
#          <span id="unv_24094377">
#          </span>
#          |
#          <a href="hide?id=24094377&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24094377">
#           80 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24097693">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           11.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24097693&amp;how=up&amp;goto=news" id="up_24097693">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://relinx.io?ref=HN" rel="nofollow">
#           Show HN: Relinx – new kind of Asset tracking – CMDB
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=relinx.io">
#            <span class="sitestr">
#             relinx.io
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24097693">
#           6 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=jelnur">
#           jelnur
#          </a>
#          <span class="age">
#           <a href="item?id=24097693">
#            1 hour ago
#           </a>
#          </span>
#          <span id="unv_24097693">
#          </span>
#          |
#          <a href="hide?id=24097693&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24097693">
#           discuss
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24097681">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           12.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24097681&amp;how=up&amp;goto=news" id="up_24097681">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://github.com/lucasepe/jumble/" rel="nofollow">
#           Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=github.com">
#            <span class="sitestr">
#             github.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24097681">
#           7 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=lucasepe">
#           lucasepe
#          </a>
#          <span class="age">
#           <a href="item?id=24097681">
#            1 hour ago
#           </a>
#          </span>
#          <span id="unv_24097681">
#          </span>
#          |
#          <a href="hide?id=24097681&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24097681">
#           discuss
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24092605">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           13.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24092605&amp;how=up&amp;goto=news" id="up_24092605">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="http://www.righto.com/2020/08/latches-inside-reverse-engineering.html">
#           Reverse-engineering the Intel 8086's instruction register
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=righto.com">
#            <span class="sitestr">
#             righto.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24092605">
#           211 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=parsecs">
#           parsecs
#          </a>
#          <span class="age">
#           <a href="item?id=24092605">
#            15 hours ago
#           </a>
#          </span>
#          <span id="unv_24092605">
#          </span>
#          |
#          <a href="hide?id=24092605&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24092605">
#           50 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24090662">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           14.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24090662&amp;how=up&amp;goto=news" id="up_24090662">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.nationalgeographic.com/animals/2020/08/new-hunting-rules-alaska-national-preserves/" rel="nofollow">
#           Why the U.S. government is allowing bears, wolves to be hunted in their dens
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=nationalgeographic.com">
#            <span class="sitestr">
#             nationalgeographic.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24090662">
#           8 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=pseudolus">
#           pseudolus
#          </a>
#          <span class="age">
#           <a href="item?id=24090662">
#            2 hours ago
#           </a>
#          </span>
#          <span id="unv_24090662">
#          </span>
#          |
#          <a href="hide?id=24090662&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24090662">
#           discuss
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24095054">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           15.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24095054&amp;how=up&amp;goto=news" id="up_24095054">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.cnbc.com/2020/08/07/spacex-and-ula-win-2022-pentagon-rocket-launch-contracts.html">
#           SpaceX and ULA win billions in Pentagon rocket contracts
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=cnbc.com">
#            <span class="sitestr">
#             cnbc.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24095054">
#           73 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=PatrolX">
#           PatrolX
#          </a>
#          <span class="age">
#           <a href="item?id=24095054">
#            11 hours ago
#           </a>
#          </span>
#          <span id="unv_24095054">
#          </span>
#          |
#          <a href="hide?id=24095054&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24095054">
#           75 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24091391">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           16.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24091391&amp;how=up&amp;goto=news" id="up_24091391">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.fieggen.com/shoelace/cialacing.htm">
#           C.I.A. Lacing (2014)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=fieggen.com">
#            <span class="sitestr">
#             fieggen.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24091391">
#           175 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=scrps">
#           scrps
#          </a>
#          <span class="age">
#           <a href="item?id=24091391">
#            18 hours ago
#           </a>
#          </span>
#          <span id="unv_24091391">
#          </span>
#          |
#          <a href="hide?id=24091391&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24091391">
#           66 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24090421">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           17.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24090421&amp;how=up&amp;goto=news" id="up_24090421">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.atlasobscura.com/articles/dark-sky-photographs">
#           The Challenges and Delights of Photographing the Night Sky
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=atlasobscura.com">
#            <span class="sitestr">
#             atlasobscura.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24090421">
#           14 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=samizdis">
#           samizdis
#          </a>
#          <span class="age">
#           <a href="item?id=24090421">
#            4 hours ago
#           </a>
#          </span>
#          <span id="unv_24090421">
#          </span>
#          |
#          <a href="hide?id=24090421&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24090421">
#           1 comment
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24097348">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           18.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24097348&amp;how=up&amp;goto=news" id="up_24097348">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="item?id=24097348">
#           Ask HN: How does your organisation train programmers?
#          </a>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24097348">
#           24 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=kqr">
#           kqr
#          </a>
#          <span class="age">
#           <a href="item?id=24097348">
#            3 hours ago
#           </a>
#          </span>
#          <span id="unv_24097348">
#          </span>
#          |
#          <a href="hide?id=24097348&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24097348">
#           9 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24090956">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           19.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24090956&amp;how=up&amp;goto=news" id="up_24090956">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://jatan.space/interviewing-isro-chandrayaan-1-mission-director/">
#           Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=jatan.space">
#            <span class="sitestr">
#             jatan.space
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24090956">
#           38 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=uncertainquark">
#           uncertainquark
#          </a>
#          <span class="age">
#           <a href="item?id=24090956">
#            8 hours ago
#           </a>
#          </span>
#          <span id="unv_24090956">
#          </span>
#          |
#          <a href="hide?id=24090956&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24090956">
#           3 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24090777">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           20.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24090777&amp;how=up&amp;goto=news" id="up_24090777">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://newrepublic.com/article/158761/learned-worst-novelist-english-language">
#           What I Learned from the Worst Novelist in the English Language
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=newrepublic.com">
#            <span class="sitestr">
#             newrepublic.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24090777">
#           32 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=pseudolus">
#           pseudolus
#          </a>
#          <span class="age">
#           <a href="item?id=24090777">
#            4 hours ago
#           </a>
#          </span>
#          <span id="unv_24090777">
#          </span>
#          |
#          <a href="hide?id=24090777&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24090777">
#           5 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24094143">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           21.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24094143&amp;how=up&amp;goto=news" id="up_24094143">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.iphoneincanada.ca/news/apple-legal-action-pear-logo/">
#           Apple takes legal action against small company with pear logo
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=iphoneincanada.ca">
#            <span class="sitestr">
#             iphoneincanada.ca
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24094143">
#           595 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=lapcatsoftware">
#           lapcatsoftware
#          </a>
#          <span class="age">
#           <a href="item?id=24094143">
#            13 hours ago
#           </a>
#          </span>
#          <span id="unv_24094143">
#          </span>
#          |
#          <a href="hide?id=24094143&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24094143">
#           245 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24093398">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           22.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24093398&amp;how=up&amp;goto=news" id="up_24093398">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.pnas.org/content/early/2020/07/21/2002655117">
#           Wheat yield potential in controlled-environment vertical farms
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=pnas.org">
#            <span class="sitestr">
#             pnas.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24093398">
#           93 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=tosh">
#           tosh
#          </a>
#          <span class="age">
#           <a href="item?id=24093398">
#            14 hours ago
#           </a>
#          </span>
#          <span id="unv_24093398">
#          </span>
#          |
#          <a href="hide?id=24093398&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24093398">
#           144 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24090607">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           23.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24090607&amp;how=up&amp;goto=news" id="up_24090607">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.atariarchives.org/deli/homebrew_and_how_the_apple.php">
#           All these companies were a lot smarter than us. What we had was luck (1984)
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=atariarchives.org">
#            <span class="sitestr">
#             atariarchives.org
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24090607">
#           61 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=janandonly">
#           janandonly
#          </a>
#          <span class="age">
#           <a href="item?id=24090607">
#            11 hours ago
#           </a>
#          </span>
#          <span id="unv_24090607">
#          </span>
#          |
#          <a href="hide?id=24090607&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24090607">
#           17 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24094259">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           24.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24094259&amp;how=up&amp;goto=news" id="up_24094259">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.scientificamerican.com/article/after-being-swallowed-alive-water-beetle-stages-backdoor-escape-from-frogs-gut/">
#           Water beetles that survive being swallowed by frogs
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=scientificamerican.com">
#            <span class="sitestr">
#             scientificamerican.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24094259">
#           53 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=zenit-mf-1">
#           zenit-mf-1
#          </a>
#          <span class="age">
#           <a href="item?id=24094259">
#            12 hours ago
#           </a>
#          </span>
#          <span id="unv_24094259">
#          </span>
#          |
#          <a href="hide?id=24094259&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24094259">
#           9 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24097763">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           25.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24097763&amp;how=up&amp;goto=news" id="up_24097763">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="item?id=24097763">
#           Ask HN: Is it a good practice to provide open-source version of your paid app?
#          </a>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24097763">
#           8 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=pmestha">
#           pmestha
#          </a>
#          <span class="age">
#           <a href="item?id=24097763">
#            1 hour ago
#           </a>
#          </span>
#          <span id="unv_24097763">
#          </span>
#          |
#          <a href="hide?id=24097763&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24097763">
#           discuss
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24090677">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           26.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24090677&amp;how=up&amp;goto=news" id="up_24090677">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.bloomberg.com/news/articles/2020-08-07/debt-collector-profits-soar-with-people-flush-and-easy-to-find">
#           Debt collector profits soar with people flush and easy to find
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=bloomberg.com">
#            <span class="sitestr">
#             bloomberg.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24090677">
#           187 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=pseudolus">
#           pseudolus
#          </a>
#          <span class="age">
#           <a href="item?id=24090677">
#            11 hours ago
#           </a>
#          </span>
#          <span id="unv_24090677">
#          </span>
#          |
#          <a href="hide?id=24090677&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24090677">
#           147 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24093044">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           27.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24093044&amp;how=up&amp;goto=news" id="up_24093044">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://news.illinois.edu/view/6367/143865832">
#           Electric cooker an easy, efficient way to sanitize N95 masks, study finds
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=illinois.edu">
#            <span class="sitestr">
#             illinois.edu
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24093044">
#           177 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=johnny313">
#           johnny313
#          </a>
#          <span class="age">
#           <a href="item?id=24093044">
#            15 hours ago
#           </a>
#          </span>
#          <span id="unv_24093044">
#          </span>
#          |
#          <a href="hide?id=24093044&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24093044">
#           94 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24090040">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           28.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24090040&amp;how=up&amp;goto=news" id="up_24090040">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://reallifemag.com/music-for-plants/">
#           Music for Plants
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=reallifemag.com">
#            <span class="sitestr">
#             reallifemag.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24090040">
#           36 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=hymnsfm">
#           hymnsfm
#          </a>
#          <span class="age">
#           <a href="item?id=24090040">
#            12 hours ago
#           </a>
#          </span>
#          <span id="unv_24090040">
#          </span>
#          |
#          <a href="hide?id=24090040&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24090040">
#           3 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24097945">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           29.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24097945&amp;how=up&amp;goto=news" id="up_24097945">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://relevantmagazine.com/life5/malcolm-gladwell-how-i-rediscovered-faith/" rel="nofollow">
#           Malcolm Gladwell: How I Rediscovered Religion
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=relevantmagazine.com">
#            <span class="sitestr">
#             relevantmagazine.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24097945">
#           3 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=hymnsfm">
#           hymnsfm
#          </a>
#          <span class="age">
#           <a href="item?id=24097945">
#            53 minutes ago
#           </a>
#          </span>
#          <span id="unv_24097945">
#          </span>
#          |
#          <a href="hide?id=24097945&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24097945">
#           1 comment
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="athing" id="24095774">
#         <td align="right" class="title" valign="top">
#          <span class="rank">
#           30.
#          </span>
#         </td>
#         <td class="votelinks" valign="top">
#          <center>
#           <a href="vote?id=24095774&amp;how=up&amp;goto=news" id="up_24095774">
#            <div class="votearrow" title="upvote">
#            </div>
#           </a>
#          </center>
#         </td>
#         <td class="title">
#          <a class="storylink" href="https://www.wsj.com/articles/twitter-tiktok-have-held-preliminary-talks-about-possible-combination-11596925449">
#           Twitter, TikTok Have Held Preliminary Talks About Possible Combination
#          </a>
#          <span class="sitebit comhead">
#           (
#           <a href="from?site=wsj.com">
#            <span class="sitestr">
#             wsj.com
#            </span>
#           </a>
#           )
#          </span>
#         </td>
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="subtext">
#          <span class="score" id="score_24095774">
#           79 points
#          </span>
#          by
#          <a class="hnuser" href="user?id=jhatax">
#           jhatax
#          </a>
#          <span class="age">
#           <a href="item?id=24095774">
#            9 hours ago
#           </a>
#          </span>
#          <span id="unv_24095774">
#          </span>
#          |
#          <a href="hide?id=24095774&amp;goto=news">
#           hide
#          </a>
#          |
#          <a href="item?id=24095774">
#           88 comments
#          </a>
#         </td>
#        </tr>
#        <tr class="spacer" style="height:5px">
#        </tr>
#        <tr class="morespace" style="height:10px">
#        </tr>
#        <tr>
#         <td colspan="2">
#         </td>
#         <td class="title">
#          <a class="morelink" href="news?p=2" rel="next">
#           More
#          </a>
#         </td>
#        </tr>
#       </table>
#      </td>
#     </tr>
#     <tr>
#      <td>
#       <img height="10" src="s.gif" width="0"/>
#       <table cellpadding="1" cellspacing="0" width="100%">
#        <tr>
#         <td bgcolor="#ff6600">
#         </td>
#        </tr>
#       </table>
#       <br/>
#       <center>
#        <span class="yclinks">
#         <a href="newsguidelines.html">
#          Guidelines
#         </a>
#         |
#         <a href="newsfaq.html">
#          FAQ
#         </a>
#         |
#         <a href="mailto:hn@ycombinator.com">
#          Support
#         </a>
#         |
#         <a href="https://github.com/HackerNews/API">
#          API
#         </a>
#         |
#         <a href="security.html">
#          Security
#         </a>
#         |
#         <a href="lists">
#          Lists
#         </a>
#         |
#         <a href="bookmarklet.html" rel="nofollow">
#          Bookmarklet
#         </a>
#         |
#         <a href="http://www.ycombinator.com/legal/">
#          Legal
#         </a>
#         |
#         <a href="http://www.ycombinator.com/apply/">
#          Apply to YC
#         </a>
#         |
#         <a href="mailto:hn@ycombinator.com">
#          Contact
#         </a>
#        </span>
#        <br/>
#        <br/>
#        <form action="//hn.algolia.com/" method="get">
#         Search:
#         <input autocapitalize="off" autocomplete="false" autocorrect="off" name="q" size="17" spellcheck="false" type="text" value=""/>
#        </form>
#       </center>
#      </td>
#     </tr>
#    </table>
#   </center>
#  </body>
#  <script src="hn.js?NuJxPWD6iCYOtPYI8iS2" type="text/javascript">
#  </script>
# </html>

# %%
names=soup.find_all('td',class_='votelinks')

# %%
titles=soup.find_all('a',class_='storylink')
title_list=[]
for i in range(0,len(titles)):
    title_list.append(titles[i].get_text())

# %%
title_list
# Out:
# ['Fire your bad customers',
#  'The German front in rare color photos, 1914-1918',
#  'There’s no such thing as a tech expert anymore',
#  'Twitter x TikTok = Twiktwok',
#  'Firefox Voice',
#  'Real Time Machine Learning (2019) [pdf]',
#  "UPI: India's Unified Payments Interface",
#  'Low-cost measurement of facemask efficacy for filtering expelled droplets',
#  'Typing Is Hard',
#  'Rome: A Linter for JavaScript and TypeScript',
#  'Show HN: Relinx – new kind of Asset tracking – CMDB',
#  'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)',
#  "Reverse-engineering the Intel 8086's instruction register",
#  'Why the U.S. government is allowing bears, wolves to be hunted in their dens',
#  'SpaceX and ULA win billions in Pentagon rocket contracts',
#  'C.I.A. Lacing (2014)',
#  'The Challenges and Delights of Photographing the Night Sky',
#  'Ask HN: How does your organisation train programmers?',
#  'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)',
#  'What I Learned from the Worst Novelist in the English Language',
#  'Apple takes legal action against small company with pear logo',
#  'Wheat yield potential in controlled-environment vertical farms',
#  'All these companies were a lot smarter than us. What we had was luck (1984)',
#  'Water beetles that survive being swallowed by frogs',
#  'Ask HN: Is it a good practice to provide open-source version of your paid app?',
#  'Debt collector profits soar with people flush and easy to find',
#  'Electric cooker an easy, efficient way to sanitize N95 masks, study finds',
#  'Music for Plants',
#  'Malcolm Gladwell: How I Rediscovered Religion',
#  'Twitter, TikTok Have Held Preliminary Talks About Possible Combination']

# %%
score=soup.find_all('span',class_='score')
score_list=[]
for i in range(0,len(score)):
    score_list.append(score[i].get_text())

# %%
score_list
# Out:
# ['114 points',
#  '115 points',
#  '35 points',
#  '230 points',
#  '159 points',
#  '105 points',
#  '240 points',
#  '35 points',
#  '147 points',
#  '201 points',
#  '6 points',
#  '7 points',
#  '211 points',
#  '8 points',
#  '73 points',
#  '175 points',
#  '14 points',
#  '24 points',
#  '38 points',
#  '32 points',
#  '595 points',
#  '93 points',
#  '61 points',
#  '53 points',
#  '8 points',
#  '187 points',
#  '177 points',
#  '36 points',
#  '3 points',
#  '79 points']

# %%
url=soup.find_all('span',class_='sitestr')
url_list=[]
for i in range(0,len(url)):
    url_list.append(url[i].get_text())

# %%
url_list
# Out:
# ['preetamnath.com',
#  'rarehistoricalphotos.com',
#  'wired.com',
#  'twiktwok.github.io',
#  'voice.mozilla.org',
#  'darpa.mil',
#  'the-other-side.blog',
#  'sciencemag.org',
#  'typing-is-hard.ch',
#  'romefrontend.dev',
#  'relinx.io',
#  'github.com',
#  'righto.com',
#  'nationalgeographic.com',
#  'cnbc.com',
#  'fieggen.com',
#  'atlasobscura.com',
#  'jatan.space',
#  'newrepublic.com',
#  'iphoneincanada.ca',
#  'pnas.org',
#  'atariarchives.org',
#  'scientificamerican.com',
#  'bloomberg.com',
#  'illinois.edu',
#  'reallifemag.com',
#  'relevantmagazine.com',
#  'wsj.com']

# %%
import pymongo
from pymongo import MongoClient
try:
    cluster=MongoClient("mongodb+srv://jyoti:1234@cluster0.fzziy.mongodb.net/1234?retryWrites=true&w=majority")
    db = cluster["test"]
    collection=db["test"]
    print("Connected")
except:
    print("Not connected")
# Out:
# Not connected
